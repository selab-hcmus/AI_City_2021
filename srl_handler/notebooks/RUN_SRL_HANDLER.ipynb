# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP' '/content'
# %cd 'TMP/srl_handler'
# Out:
# /content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/srl_handler

# %%
# !pip install webcolors
# Out:
# Collecting webcolors
#   Downloading https://files.pythonhosted.org/packages/12/05/3350559de9714b202e443a9e6312937341bd5f79f4e4f625744295e7dd17/webcolors-1.11.1-py3-none-any.whl
# Installing collected packages: webcolors
# Successfully installed webcolors-1.11.1

# %%
# !python color_prep.py
# Out:
# RUN TEST
# 100% 530/530 [00:01<00:00, 500.20it/s]
# save result to ./results directory
# Fail queries: []

# %%
# !python veh_prep.py
# Out:
# RUN TEST
# 100% 530/530 [00:01<00:00, 500.91it/s]
# Extract dataframe to ./results/veh_test_fraction.csv
# Fail queries: []
# 100% 530/530 [00:01<00:00, 514.48it/s]
# Extract dataframe to ./results/veh_test.csv
# Fail queries: []

# %%
# !python action_prep.py
# Out:
# {'turn': 0, 'curve': 0, 'bare': 0, 'stop': 1, 'park': 1, 'wait': 1, 'pause': 1, 'run': 2, 'go': 2, 'drive': 2, 'keep': 2, 'cross': 2, 'move': 2, 'continue': 2, 'travel': 2, 'proceed': 2, 'merge': 2, 'switch': 2, 'change': 2}
# 100% 530/530 [00:01<00:00, 511.02it/s]
# save result to ./results directory
# 0 fail queries: []
# 100% 530/530 [00:01<00:00, 518.09it/s]
# save result to ./results directory
# 0 fail queries: []
