# %%
# !nvidia-smi
# Out:
# Mon May 10 01:08:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP' '/content'

# %%
# %cd 'TMP/retrieval_model'
# Out:
# [Errno 2] No such file or directory: 'TMP/retrieval_model'
# /content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/retrieval_model

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.1MB 17.7MB/s
# ...
#      |████████████████████████████████| 10.1MB 48.1MB/s
# ...
#      |████████████████████████████████| 21.6MB 1.3MB/s
# ...
#      |████████████████████████████████| 51kB 9.0MB/s
# ...
#      |████████████████████████████████| 358kB 51.0MB/s
# ...
#      |████████████████████████████████| 104.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.3MB 54.2MB/s
# ...
#      |████████████████████████████████| 901kB 49.9MB/s
# ...
#      |████████████████████████████████| 245kB 58.4MB/s
# ...
#      |████████████████████████████████| 747kB 47.3MB/s
# ...
#      |████████████████████████████████| 225kB 59.2MB/s
# ...
#      |████████████████████████████████| 112kB 58.0MB/s
# ...
#      |████████████████████████████████| 61kB 9.5MB/s
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-cp37-none-any.whl size=7411 sha256=d13da6ff9ecc4bb52535b15612fb5229814975934a33da66933af1bca35dc589
#   Stored in directory: /root/.cache/pip/wheels/3d/77/07/80562de4bb0786e5ea186911a2c831fdd0018bda69beab71fd
# ...

# %%
# !echo $PWD
# Out:
# /content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/retrieval_model

# %%
# !rm -r '/content/TMP/retrieval_model/data/TEST'
# !rm -r '/content/TMP/retrieval_model/data/TRAIN'

# %%
# !chmod +x script/PREPARE.sh
# !sh script/PREPARE.sh
# Out:
# ******************** Loading model bert-base-uncased from transformers
# Running model on device cuda:0
# Maximum input length 512
# Init model successfully
# Load textual data successfully
# Compute total_words and max_words: 100% 2498/2498 [00:00<00:00, 359096.94it/s]
# Total 68347 average 27.36 max 52
# ******************** Loading and testing dataset.
# key: 189bd009-a5db-4103-9edf-754126b34a42
#
# text: ['[CLS] A silver car is driving in the right lane around a curve [SEP]', 'A grey sedan turning right [SEP]', 'A silver vehicle in traffic on the main street [SEP]']
#
# text_tokenized: [['[CLS]', 'a', 'silver', 'car', 'is', 'driving', 'in', 'the', 'right', 'lane', 'around', 'a', 'curve', '[SEP]'], ['a', 'grey', 'sedan', 'turning', 'right', '[SEP]'], ['a', 'silver', 'vehicle', 'in', 'traffic', 'on', 'the', 'main', 'street', '[SEP]']]
#
# tokens: tensor([  101,  1037,  3165,  2482,  2003,  4439,  1999,  1996,  2157,  4644,
# ...

# %%
# !chmod +x script/TRAIN.sh
# !sh script/TRAIN.sh

# %%
# !python tools/train.py -c 'config/retrieval/paper2020/aic21_6148_atn1.yaml' --load_model 'experiments/aic21_6148_atn1_run1/models/model_23_r1.pth' --uptrain

# %%
# !chmod +x script/INFERENCE.sh
# !sh script/INFERENCE.sh
# Out:
# Source config: config/retrieval/paper2020/aic21_6148_atn1.yaml
# Results path:  experiments/aic21_6148_atn1
# path_data: data
# ********************Init dataset
# Analyzing features: 530it [00:00, 10595.11it/s]
#
# ********************Create Model
#
# ********************Start Inference
# EMBEDDING VIDEO
# 100% 530/530 [00:06<00:00, 87.23it/s]
# save video emb to ./results/embedding/video_emb.pickle
# EMBEDDING TEXT
# 100% 530/530 [00:03<00:00, 160.14it/s]
# save text emb to ./results/embedding/text_emb.pickle
# Get final results
# par_emb_mat shape: (530, 384)
# vid_emb_mat shape: (530, 384)
# 530it [00:00, 4632.40it/s]
# save submission file to ./results/result.json
