# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE' '/content'
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021' '/content'
# !ln -s '/content/AI_CITY_2021/SOURCE/open_source/coot-aic' '/content'
# Out:
# ln: failed to create symbolic link '/content/SOURCE': File exists
# ln: failed to create symbolic link '/content/AI_CITY_2021': File exists
# ln: failed to create symbolic link '/content/coot-aic': File exists

# %%
# %cd /content/SOURCE/TMP/refinement
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/SOURCE/TMP/refinement

# %% [markdown]
# # Dependencies

# %%
import os, json, cv2
import os.path as osp 
from tqdm.notebook import tqdm
import numpy as np
import json
import pandas as pd

# %% [markdown]
# # Run refinement

# %%
# !python main.py
# Out:
# Refined result will be saved to ./results/result_refine.json
# 100% 530/530 [00:20<00:00, 25.96it/s]
# Save result to ./results/result_refine.json
