# %%
# !nvidia-smi
# Out:
# Mon May 10 02:59:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget "https://studenthcmusedu-my.sharepoint.com/:u:/g/personal/1712122_student_hcmus_edu_vn/EUzbsyLVX-NJvGJvUsmd5MMB7NFQfC5J_0nB3zSnV5XcMQ?e=UqFBGb&download=1" -O /content/data.zip
# Out:
# --2021-05-10 03:00:35--  https://studenthcmusedu-my.sharepoint.com/:u:/g/personal/1712122_student_hcmus_edu_vn/EUzbsyLVX-NJvGJvUsmd5MMB7NFQfC5J_0nB3zSnV5XcMQ?e=UqFBGb&download=1
# Resolving studenthcmusedu-my.sharepoint.com (studenthcmusedu-my.sharepoint.com)... 13.107.136.9
# Connecting to studenthcmusedu-my.sharepoint.com (studenthcmusedu-my.sharepoint.com)|13.107.136.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/1712122_student_hcmus_edu_vn/Documents/THESIS_info/[AICity_2021]-data/test_imgs.zip?originalPath=aHR0cHM6Ly9zdHVkZW50aGNtdXNlZHUtbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvMTcxMjEyMl9zdHVkZW50X2hjbXVzX2VkdV92bi9FVXpic3lMVlgtTkp2R0p2VXNtZDVNTUI3TkZRZkM1Sl8wbkIzelNuVjVYY01RP3J0aW1lPUJBUGR5RjhUMlVn [following]
# ...

# %%
# %%capture
# !unzip -d '/content' '/content/data.zip'

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP' '/content'

# %%
# %cd /content/TMP/classifier
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/SOURCE/TMP/classifier

# %% [markdown]
# # Run prediction

# %%
# !python label_prediction.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Loaded pretrained weights for efficientnet-b5
# Loaded pretrained weights for efficientnet-b5
# 100% 530/530 [05:12<00:00,  1.70it/s]
# 100% 530/530 [05:11<00:00,  1.70it/s]
