# %%
# !nvidia-smi
# Out:
# Sun May 23 10:09:02 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/AI_City_2021/' '/content'

# %%
# %cd '/content/AI_City_2021/classifier'
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier

# %%
# %cd 'EfficientNet-PyTorch'
# !pip install -e . 
# %cd '../'
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier/EfficientNet-PyTorch
# Obtaining file:///content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier/EfficientNet-PyTorch
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.7.1) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (3.7.4.3)
# Installing collected packages: efficientnet-pytorch
#   Running setup.py develop for efficientnet-pytorch
# Successfully installed efficientnet-pytorch
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier

# %% [markdown]
# # Train classifier

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Loaded pretrained weights for efficientnet-b5
# Loaded pretrained weights for efficientnet-b5
# TRAIN VEHICLE
# Replaced box dir successfully
# Dropped duplicated rows
# 8052 2024
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# train dataset: 8052
# val dataset: 2024
# img shape: torch.Size([3, 224, 224])
# label shape: torch.Size([6])
# Created save directory
# --------------------
# Epoch 0/19
# 100% 504/504 [33:17<00:00,  3.96s/it]
# [train, epoch 0/20] Loss: 152.6214, Acc: 0.6343
# 100% 253/253 [05:38<00:00,  1.34s/it]
# [val, epoch 0/20] Loss: 20.6563, Acc: 0.8409
# save best model at 0
# --------------------
# Epoch 1/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 1/20] Loss: 69.6622, Acc: 0.8639
# 100% 253/253 [00:17<00:00, 14.56it/s]
# [val, epoch 1/20] Loss: 14.5634, Acc: 0.8985
# save best model at 1
# --------------------
# Epoch 2/19
# 100% 504/504 [02:43<00:00,  3.07it/s]
# [train, epoch 2/20] Loss: 51.6961, Acc: 0.9131
# 100% 253/253 [00:17<00:00, 14.22it/s]
# [val, epoch 2/20] Loss: 14.0077, Acc: 0.9066
# save best model at 2
# --------------------
# Epoch 3/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 3/20] Loss: 39.1354, Acc: 0.9400
# 100% 253/253 [00:17<00:00, 14.55it/s]
# [val, epoch 3/20] Loss: 12.7260, Acc: 0.9219
# save best model at 3
# --------------------
# Epoch 4/19
# 100% 504/504 [02:43<00:00,  3.07it/s]
# [train, epoch 4/20] Loss: 31.6962, Acc: 0.9586
# 100% 253/253 [00:17<00:00, 14.54it/s]
# [val, epoch 4/20] Loss: 12.4110, Acc: 0.9222
# save best model at 4
# --------------------
# Epoch 5/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 5/20] Loss: 25.6203, Acc: 0.9690
# 100% 253/253 [00:17<00:00, 14.63it/s]
# [val, epoch 5/20] Loss: 13.2126, Acc: 0.9158
# --------------------
# Epoch 6/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 6/20] Loss: 22.0136, Acc: 0.9731
# 100% 253/253 [00:17<00:00, 14.50it/s]
# [val, epoch 6/20] Loss: 13.0647, Acc: 0.9190
# --------------------
# Epoch 7/19
# 100% 504/504 [02:43<00:00,  3.07it/s]
# [train, epoch 7/20] Loss: 19.6730, Acc: 0.9766
# 100% 253/253 [00:17<00:00, 14.50it/s]
# [val, epoch 7/20] Loss: 15.8153, Acc: 0.8938
# --------------------
# Epoch 8/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 8/20] Loss: 17.9218, Acc: 0.9781
# 100% 253/253 [00:17<00:00, 14.49it/s]
# [val, epoch 8/20] Loss: 15.2647, Acc: 0.8930
# --------------------
# Epoch 9/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 9/20] Loss: 14.8295, Acc: 0.9832
# 100% 253/253 [00:17<00:00, 14.36it/s]
# [val, epoch 9/20] Loss: 13.9187, Acc: 0.9160
# --------------------
# Epoch 10/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 10/20] Loss: 12.9806, Acc: 0.9852
# 100% 253/253 [00:17<00:00, 14.15it/s]
# [val, epoch 10/20] Loss: 13.1054, Acc: 0.9227
# --------------------
# Epoch 11/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 11/20] Loss: 10.3464, Acc: 0.9898
# 100% 253/253 [00:17<00:00, 14.53it/s]
# [val, epoch 11/20] Loss: 13.8714, Acc: 0.9217
# --------------------
# Epoch 12/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 12/20] Loss: 10.1295, Acc: 0.9896
# 100% 253/253 [00:17<00:00, 14.48it/s]
# [val, epoch 12/20] Loss: 13.4710, Acc: 0.9219
# --------------------
# Epoch 13/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 13/20] Loss: 10.1722, Acc: 0.9883
# 100% 253/253 [00:17<00:00, 14.64it/s]
# [val, epoch 13/20] Loss: 14.7247, Acc: 0.9113
# --------------------
# Epoch 14/19
# 100% 504/504 [02:43<00:00,  3.08it/s]
# [train, epoch 14/20] Loss: 8.7602, Acc: 0.9894
# 100% 253/253 [00:17<00:00, 14.64it/s]
# [val, epoch 14/20] Loss: 14.2327, Acc: 0.9145
# --------------------
# Epoch 15/19
# 100% 504/504 [02:43<00:00,  3.07it/s]
# [train, epoch 15/20] Loss: 7.6153, Acc: 0.9921
# 100% 253/253 [00:17<00:00, 14.57it/s]
# [val, epoch 15/20] Loss: 14.4129, Acc: 0.9096
# --------------------
# Epoch 16/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 16/20] Loss: 7.1288, Acc: 0.9922
# 100% 253/253 [00:17<00:00, 14.54it/s]
# [val, epoch 16/20] Loss: 14.5728, Acc: 0.9098
# --------------------
# Epoch 17/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 17/20] Loss: 7.7900, Acc: 0.9894
# 100% 253/253 [00:17<00:00, 14.51it/s]
# [val, epoch 17/20] Loss: 14.4693, Acc: 0.9103
# --------------------
# Epoch 18/19
# 100% 504/504 [02:44<00:00,  3.07it/s]
# [train, epoch 18/20] Loss: 6.4184, Acc: 0.9924
# 100% 253/253 [00:17<00:00, 14.61it/s]
# [val, epoch 18/20] Loss: 14.1085, Acc: 0.9118
# --------------------
# Epoch 19/19
# 100% 504/504 [02:43<00:00,  3.07it/s]
# [train, epoch 19/20] Loss: 6.7902, Acc: 0.9911
# 100% 253/253 [00:17<00:00, 14.62it/s]
# [val, epoch 19/20] Loss: 13.5956, Acc: 0.9153
# Training complete in 96m 27s
# Best val Acc: 0.000000

# %% [markdown]
# # Extract feature
# Extract visual feature for retrieval step using the above classifier

# %%
# !python extract_feat.py

# %% [markdown]
# # Visualize prediction

# %%
# !python visualize_prediction.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Loaded pretrained weights for efficientnet-b5
# Loaded pretrained weights for efficientnet-b5
# 2024it [02:37, 12.82it/s]
