# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021' '/content'
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP' '/content'
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE' '/content'
# Out:
# ln: failed to create symbolic link '/content/TMP': File exists
# ln: failed to create symbolic link '/content/SOURCE': File exists

# %%
# %cd 'TMP/classifier'
# Out:
# /content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/classifier

# %%
# %cd 'EfficientNet-PyTorch'
# !pip install -e . 
# %cd '../'
# Out:
# /content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/classifier/EfficientNet-PyTorch
# Obtaining file:///content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/TMP/classifier/EfficientNet-PyTorch
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.7.1) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (3.7.4.3)
# Installing collected packages: efficientnet-pytorch
#   Running setup.py develop for efficientnet-pytorch
# Successfully installed efficientnet-pytorch
# /content/drive/My Drive/THESIS/AI_CITY_2021/SOURCE/TMP/classifier

# %% [markdown]
# # Train classifier

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b5-b6417697.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b5-b6417697.pth
# 100% 117M/117M [00:02<00:00, 53.1MB/s]
# Loaded pretrained weights for efficientnet-b5
# Loaded pretrained weights for efficientnet-b5
# TRAIN VEHICLE
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# train dataset: 7984
# val dataset: 1996
# img shape: torch.Size([3, 224, 224])
# label shape: torch.Size([6])
# --------------------
# Epoch 0/19
#  20% 102/499 [06:26<20:01,  3.03s/it]

# %% [markdown]
# # Extract feature
# Extract visual feature for retrieval step using the above classifier

# %%
# !python extract_feat.py
