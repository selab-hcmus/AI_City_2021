# %%
# !nvidia-smi
# Out:
# Sun May 23 07:53:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
train_tracks = json.load(open("/content/train-tracks.json"))
test_tracks = json.load(open("/content/test-tracks.json"))
test_queries = json.load(open("/content/test-queries.json"))

count = 0
ans = []
for key in train_tracks:
    ans.append({
        "key": key,
        "order": count
    })
    count += 1
train_tracks_df = pd.DataFrame(data=ans)


count = 0
ans = []
for key in test_tracks:
    ans.append({
        "key": key,
        "order": count
    })
    count += 1
test_tracks_df = pd.DataFrame(data=ans)


count = 0
ans = []
for key in test_queries:
    ans.append({
        "key": key,
        "order": count
    })
    count += 1
test_queries_df = pd.DataFrame(data=ans)

# %%
train_tracks_df.to_csv("/content/AI_City_2021/utils/train_tracks_order.csv", index=False)
test_tracks_df.to_csv("/content/AI_City_2021/utils/test_tracks_order.csv", index=False)
test_queries_df.to_csv("/content/AI_City_2021/utils/test_queries_order.csv", index=False)

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/AI_City_2021/' '/content'

# %%
# %cd '/content/AI_City_2021/classifier'
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier

# %%
# %cd 'EfficientNet-PyTorch'
# !pip install -e . 
# %cd '../'
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier/EfficientNet-PyTorch
# Obtaining file:///content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier/EfficientNet-PyTorch
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.7.1) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.7.1) (3.7.4.3)
# Installing collected packages: efficientnet-pytorch
#   Running setup.py develop for efficientnet-pytorch
# Successfully installed efficientnet-pytorch
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/AI_City_2021/classifier

# %% [markdown]
# # Train classifier

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Loaded pretrained weights for efficientnet-b5
# Loaded pretrained weights for efficientnet-b5
# TRAIN VEHICLE
# Replaced box dir successfully
# Dropped duplicated rows
# 8052 2024
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# train dataset: 8052
# val dataset: 2024
# img shape: torch.Size([3, 224, 224])
# label shape: torch.Size([6])
# Created save directory
# --------------------
# Epoch 0/19
# 100% 504/504 [17:58<00:00,  2.14s/it]
# [train, epoch 0/20] Loss: 130.2544, Acc: 0.6748
# 100% 253/253 [04:08<00:00,  1.02it/s]
# [val, epoch 0/20] Loss: 19.6536, Acc: 0.8562
# save best model at 0
# --------------------
# Epoch 1/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 1/20] Loss: 74.2318, Acc: 0.8639
# 100% 253/253 [00:19<00:00, 13.00it/s]
# [val, epoch 1/20] Loss: 16.3009, Acc: 0.8943
# save best model at 1
# --------------------
# Epoch 2/19
# 100% 504/504 [03:56<00:00,  2.13it/s]
# [train, epoch 2/20] Loss: 54.8854, Acc: 0.9195
# 100% 253/253 [00:19<00:00, 13.14it/s]
# [val, epoch 2/20] Loss: 15.0182, Acc: 0.9121
# save best model at 2
# --------------------
# Epoch 3/19
# 100% 504/504 [03:56<00:00,  2.13it/s]
# [train, epoch 3/20] Loss: 47.5591, Acc: 0.9407
# 100% 253/253 [00:19<00:00, 13.08it/s]
# [val, epoch 3/20] Loss: 16.9047, Acc: 0.8928
# --------------------
# Epoch 4/19
# 100% 504/504 [03:56<00:00,  2.13it/s]
# [train, epoch 4/20] Loss: 42.6518, Acc: 0.9537
# 100% 253/253 [00:19<00:00, 13.10it/s]
# [val, epoch 4/20] Loss: 15.3117, Acc: 0.9027
# --------------------
# Epoch 5/19
# 100% 504/504 [03:56<00:00,  2.13it/s]
# [train, epoch 5/20] Loss: 37.5825, Acc: 0.9682
# 100% 253/253 [00:19<00:00, 12.98it/s]
# [val, epoch 5/20] Loss: 16.2411, Acc: 0.8992
# --------------------
# Epoch 6/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 6/20] Loss: 35.4446, Acc: 0.9722
# 100% 253/253 [00:19<00:00, 13.12it/s]
# [val, epoch 6/20] Loss: 14.1987, Acc: 0.9140
# save best model at 6
# --------------------
# Epoch 7/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 7/20] Loss: 33.1145, Acc: 0.9773
# 100% 253/253 [00:19<00:00, 13.00it/s]
# [val, epoch 7/20] Loss: 14.7499, Acc: 0.9054
# --------------------
# Epoch 8/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 8/20] Loss: 32.3307, Acc: 0.9775
# 100% 253/253 [00:19<00:00, 13.01it/s]
# [val, epoch 8/20] Loss: 13.7910, Acc: 0.9187
# save best model at 8
# --------------------
# Epoch 9/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 9/20] Loss: 30.4307, Acc: 0.9816
# 100% 253/253 [00:19<00:00, 13.04it/s]
# [val, epoch 9/20] Loss: 13.6298, Acc: 0.9222
# save best model at 9
# --------------------
# Epoch 10/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 10/20] Loss: 28.0997, Acc: 0.9867
# 100% 253/253 [00:19<00:00, 13.03it/s]
# [val, epoch 10/20] Loss: 13.9843, Acc: 0.9160
# --------------------
# Epoch 11/19
# 100% 504/504 [03:56<00:00,  2.13it/s]
# [train, epoch 11/20] Loss: 28.5979, Acc: 0.9848
# 100% 253/253 [00:19<00:00, 13.09it/s]
# [val, epoch 11/20] Loss: 12.9672, Acc: 0.9291
# save best model at 11
# --------------------
# Epoch 12/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 12/20] Loss: 27.6462, Acc: 0.9853
# 100% 253/253 [00:19<00:00, 12.99it/s]
# [val, epoch 12/20] Loss: 14.1090, Acc: 0.9150
# --------------------
# Epoch 13/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 13/20] Loss: 26.0444, Acc: 0.9888
# 100% 253/253 [00:19<00:00, 12.91it/s]
# [val, epoch 13/20] Loss: 14.6381, Acc: 0.9133
# --------------------
# Epoch 14/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 14/20] Loss: 25.6621, Acc: 0.9901
# 100% 253/253 [00:19<00:00, 13.03it/s]
# [val, epoch 14/20] Loss: 13.8906, Acc: 0.9170
# --------------------
# Epoch 15/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 15/20] Loss: 25.1961, Acc: 0.9898
# 100% 253/253 [00:19<00:00, 13.04it/s]
# [val, epoch 15/20] Loss: 13.1751, Acc: 0.9239
# --------------------
# Epoch 16/19
# 100% 504/504 [03:57<00:00,  2.12it/s]
# [train, epoch 16/20] Loss: 24.4291, Acc: 0.9911
# 100% 253/253 [00:19<00:00, 12.92it/s]
# [val, epoch 16/20] Loss: 14.1428, Acc: 0.9145
# --------------------
# Epoch 17/19
# 100% 504/504 [03:57<00:00,  2.12it/s]
# [train, epoch 17/20] Loss: 24.1744, Acc: 0.9912
# 100% 253/253 [00:19<00:00, 12.81it/s]
# [val, epoch 17/20] Loss: 13.9170, Acc: 0.9222
# --------------------
# Epoch 18/19
# 100% 504/504 [03:57<00:00,  2.12it/s]
# [train, epoch 18/20] Loss: 23.1256, Acc: 0.9932
# 100% 253/253 [00:19<00:00, 13.05it/s]
# [val, epoch 18/20] Loss: 13.4660, Acc: 0.9232
# --------------------
# Epoch 19/19
# 100% 504/504 [03:57<00:00,  2.13it/s]
# [train, epoch 19/20] Loss: 23.4841, Acc: 0.9907
# 100% 253/253 [00:19<00:00, 13.01it/s]
# [val, epoch 19/20] Loss: 14.0626, Acc: 0.9135
# Training complete in 103m 29s
# Best val Acc: 0.000000

# %% [markdown]
# # Extract feature
# Extract visual feature for retrieval step using the above classifier

# %%
# !python extract_feat.py
