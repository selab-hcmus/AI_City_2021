# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ln -s '/content/drive/MyDrive/THESIS/AI_CITY_2021/SOURCE/' '/content'

# %%
# %cd '/content/SOURCE/TMP/srl_extraction'
# Out:
# /content/drive/.shortcut-targets-by-id/188VW9DNUCL5HucDJeTzOMLyF0U0lA1-0/THESIS/AI_CITY_2021/SOURCE/TMP/srl_extraction

# %% [markdown]
# # Install dependencies

# %%
# !pip install allennlp==2.0.0 -q
# !pip install allennlp-models==1.4.0 -q
# !pip install tqdm -q
# !pip install webcolors
# !pip install python-Levenshtein

# %% [markdown]
# # Import dependencies

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import json
import re
from tqdm.notebook import tqdm
import pandas as pd
import random
import webcolors
from matplotlib.colors import is_color_like
from allennlp.predictors.predictor import Predictor
import Levenshtein
import spacy
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# # Run SRL

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Plugin allennlp_models could not be loaded: No module named 'nltk.translate.meteor_score'
#   4% 19/530 [00:14<05:22,  1.58it/s](1) 20_1: white mini cooper.
#   5% 29/530 [00:21<06:06,  1.37it/s](2) 30_2: a white suv among other vehicles.
#  13% 69/530 [00:47<05:09,  1.49it/s](3) 70_1: a green go to the straight.
#  15% 82/530 [00:55<04:48,  1.55it/s](4) 83_3: a maroon car.
#  25% 133/530 [01:29<04:12,  1.58it/s](5) 134_1: it a blue hatchback.
#  26% 137/530 [01:32<03:59,  1.64it/s](6) 138_3: a black midsize crossover suv.
#  31% 164/530 [01:50<03:54,  1.56it/s](7) 165_1: a cargo-truck with a flatbed drove straight.
#  32% 171/530 [01:54<03:48,  1.57it/s](8) 172_3: door sedan luxury car and its very simple with beautiful.
#  55% 293/530 [03:16<02:35,  1.52it/s](9) 294_3: sedan medium and agile.
#  56% 298/530 [03:20<02:49,  1.37it/s](10) 299_2: gray coupe with a dark-colored car behind it.
#  57% 300/530 [03:21<02:41,  1.43it/s](11) 301_2: a post office car.
#  57% 304/530 [03:23<02:27,  1.53it/s](12) 305_3: a black midsize crossover suv.
#  65% 347/530 [03:53<02:01,  1.51it/s](13) 348_2: it a blue hatchback.
#  73% 387/530 [04:20<01:33,  1.53it/s](14) 388_3: a green go to the straight.
#  76% 401/530 [04:29<01:24,  1.53it/s](15) 402_1: a door white pickup .
#  81% 430/530 [04:48<01:10,  1.42it/s](16) 431_3: a black midsize crossover suv.
#  85% 450/530 [05:01<00:51,  1.56it/s](17) 451_3: a green go to the straight.
#  86% 455/530 [05:04<00:48,  1.54it/s](18) 456_2: a red suv.
#  88% 465/530 [05:11<00:45,  1.41it/s](19) 466_3: black suv behind another suv.
#  95% 501/530 [05:35<00:21,  1.38it/s](20) 502_3: a black midsize crossover suv.
#  98% 522/530 [05:50<00:05,  1.50it/s](21) 523_1: a red suv.
# 100% 530/530 [05:56<00:00,  1.49it/s]
# 100% 11/11 [00:00<00:00, 93018.84it/s]
